# %% [markdown]
# # Process PSID dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import xmltodict

# %% [markdown]
# ## Parse the .xml codebook

# %%
with open("../data/psid/J322088_codebook.xml", "r", encoding = "cp1252") as file:
    xml_text = file.read()
file.close()

# %%
codebook_dict = xmltodict.parse(xml_text)
codebook_dict = codebook_dict["CODEXML"]['LIST_JOBID']['JOBID']['LIST_VARIABLE']['VARIABLE']

# %%
codebook_df = pd.DataFrame(codebook_dict)
codebook_df
# Out:
#      YEAR TYPE_ID     NAME                                     LABEL  \
# 0    1968       0  ER30000                            RELEASE NUMBER
# 1    1968       0  ER30001                     1968 INTERVIEW NUMBER
# 2    1968       0  ER30002  PERSON NUMBER                         68
# 3    2001       1  ER17001                            RELEASE NUMBER
# 4    2001       1  ER17002         2001 FAMILY INTERVIEW (ID) NUMBER
# ..    ...     ...      ...                                       ...
# 428  2021       1  ER81836      IMP WEALTH W/O EQUITY (WEALTH1) 2021
# 429  2021       1  ER81838       IMP WEALTH W/ EQUITY (WEALTH2) 2021
# 430  2021       2  ER34901                     2021 INTERVIEW NUMBER
# 431  2021       2  ER34902  SEQUENCE NUMBER                       21
# 432  2021       2  ER34903  RELATION TO REFERENCE PERSON          21
#
#                                               QTEXT  \
# 0                                    Release Number
# 1            1968 Interview Number (1968 ID Number)
# 2                                     Person Number
# 3                                    Release Number
# 4                             2001 Interview Number
# ..                                              ...
# 428   Constructed Wealth Variable, Excluding Equity
# 429  Constructed Wealth Variable, Including Equity.
# 430          2021 Interview Number (2021 ID Number)
# 431                            2021 Sequence Number
# 432           2021 Relationship to Reference Person
#
#                                                  ETEXT  \
# 0                                                 None
# 1    This variable is the 1968 family ID number. Th...
# 2                                                 None
# 3    May 2008:  Variables ER20395-ER20458, formerly...
# 4    The values for this variable represent the 200...
# ..                                                 ...
# 428  Constructed wealth variable, excluding equity....
# 429  Constructed wealth variable, including equity....
# 430  The values for this variable represent the 202...
# 431  This variable provides a means of identifying ...
# 432  Note that these relationships are those to the...
#
#                                              LIST_CODE
# 0    {'CODE': {'VALUE': '1', 'TEXT': 'Release numbe...
# 1    {'CODE': [{'VALUE': '1 - 2,930', 'TEXT': 'Memb...
# 2    {'CODE': [{'VALUE': '1 - 19', 'TEXT': 'Individ...
# 3    {'CODE': [{'VALUE': '1', 'TEXT': 'Release numb...
# 4    {'CODE': {'VALUE': '1 - 7,457', 'TEXT': 'Inter...
# ..                                                 ...
# 428  {'CODE': [{'VALUE': '-99,999,997 - -1', 'TEXT'...
# 429  {'CODE': [{'VALUE': '-99,999,997 - -1', 'TEXT'...
# 430  {'CODE': [{'VALUE': '1 - 9,614', 'TEXT': '2021...
# 431  {'CODE': [{'VALUE': '1 - 20', 'TEXT': 'Individ...
# 432  {'CODE': [{'VALUE': '10', 'TEXT': 'Reference P...
#
# [433 rows x 7 columns]

# %%
# standardize the column/label names
def label_reorg_func(label:str):
    if "FAMILY INTERVIEW (ID) NUMBER" in label:
        return "family_interview_id"
    if "TOTAL FAMILY INCOME" in label:
        return "total_family_income"
    if "WTR DONATED TO ORGANIZATN FOR HEALTH" in label:
        return "wtr_donated_to_health_org"
    if "DOLLAR AMT OF HEALTH DONATIONS" in label:
        return "amt_of_health_donations"
    if "SEQUENCE NUMBER" in label:
        return "sequence_number"
    if "SEX OF" in label:
        return "sex"
    if "RELATION TO" in label:
        return "relation_to_rp"
    if "CHILDREN" in label:
        return "number_of_children_in_fu"
    if ("HEALTH" in label) and ("STATUS" in label):
        return "health_status"
    if "RELIGIOUS PREF" in label:
        return "religion"
    if "MARITAL STATUS" in label:
        return "marital_status"
    if "RACE OF" in label:
        return "race"
    if "AGE OF" in label:
        return "age"
    if "IMP WEALTH W/O EQUITY" in label:
        return "wealth_wo_equity"
    if "IMP WEALTH W/ EQUITY" in label:
        return "wealth_with_equity"
    if "WTR DONATION&gt;25" in label:
        return "wtr_donated" 
    if "WTR DONATED TO RELIGIOUS ORGANIZATION" in label:
        return "wtr_donated_to_religious_org"
    if "DOLLAR AMT OF RELIGIOUS DONATIONS" in label:
        return "amt_of_religious_donations"
    if "WTR DONATD TO COMBO PURPOSE ORGANIZTN" in label:
        return "wtr_donated_to_combo_purpose_org"
    if "DOLLAR AMT OF COMBO DONATIONS" in label:
        return "amt_of_combo_donations"
    if "WTR DONATED TO ORGANIZATION FOR NEEDY" in label:
        return "wtr_donated_to_org_for_needy"
    if "DOLLAR AMT OF NEEDY DONATIONS" in label:
        return "amt_of_needy_donations"
    if "WTR DONATED TO ORGANZTION FOR EDUCATN" in label:
        return "wtr_donated_to_edu_org"
    if "DOLLAR AMT OF EDUCATION DONATIONS" in label:
        return "amt_of_edu_donations"
    if "WTR DONATED TO YOUTH ORGANIZATIONS" in label:
        return "wtr_donated_to_youth_org"
    if "DOLLAR AMT OF YOUTH ORG DONATIONS" in label:
        return "amt_of_youth_donations"
    if "WTR DONATED TO CULTURAL ORGS" in label:
        return "wtr_donated_to_cultural_org"
    if "DOLLAR AMT OF CULTURAL DONATIONS" in label:
        return "amt_of_cultural_donations"
    if "WTR DONATED TO COMMUNITY ORGS" in label:
        return "wtr_donated_to_community_org"
    if "DOLLAR AMT OF COMMUNITY DONATIONS" in label:
        return "amt_of_community_donations"
    if "WTR DONATED TO ENVIRONMENT ORGS" in label:
        return "wtr_donated_to_env_org"
    if "DOLLAR AMT OF ENVIRONMENT DONATION" in label:
        return "amt_of_env_donations"
    if "WTR DONATED TO OTHER ORGANIZATIONS" in label:
        return "wtr_donated_to_other"
    if ("AMT DONATED TO ORGS IN T7A-F" in label) or ("DOLLAR AMT OF OTHER DONATIONS" in label):
        return "amt_of_other_donations"
    if "WTR DONATED TO INTERNATL/PEACE ORG" in label:
        return "wtr_donated_intl/peace_org"
    if "DOLLAR AMT OF INTERNATL/PEACE DNTN" in label:
        return "amt_of_intl/peace_donations"
    if "PERSON NUMBER" in label:
        return "person_number"
    return label.replace(" ", "_").lower()

codebook_df["STANDARDIZED_LABEL"] = codebook_df.LABEL.apply(label_reorg_func)
codebook_df
# Out:
#      YEAR TYPE_ID     NAME                                     LABEL  \
# 0    1968       0  ER30000                            RELEASE NUMBER
# 1    1968       0  ER30001                     1968 INTERVIEW NUMBER
# 2    1968       0  ER30002  PERSON NUMBER                         68
# 3    2001       1  ER17001                            RELEASE NUMBER
# 4    2001       1  ER17002         2001 FAMILY INTERVIEW (ID) NUMBER
# ..    ...     ...      ...                                       ...
# 428  2021       1  ER81836      IMP WEALTH W/O EQUITY (WEALTH1) 2021
# 429  2021       1  ER81838       IMP WEALTH W/ EQUITY (WEALTH2) 2021
# 430  2021       2  ER34901                     2021 INTERVIEW NUMBER
# 431  2021       2  ER34902  SEQUENCE NUMBER                       21
# 432  2021       2  ER34903  RELATION TO REFERENCE PERSON          21
#
#                                               QTEXT  \
# 0                                    Release Number
# 1            1968 Interview Number (1968 ID Number)
# 2                                     Person Number
# 3                                    Release Number
# 4                             2001 Interview Number
# ..                                              ...
# 428   Constructed Wealth Variable, Excluding Equity
# 429  Constructed Wealth Variable, Including Equity.
# 430          2021 Interview Number (2021 ID Number)
# 431                            2021 Sequence Number
# 432           2021 Relationship to Reference Person
#
#                                                  ETEXT  \
# 0                                                 None
# 1    This variable is the 1968 family ID number. Th...
# 2                                                 None
# 3    May 2008:  Variables ER20395-ER20458, formerly...
# 4    The values for this variable represent the 200...
# ..                                                 ...
# 428  Constructed wealth variable, excluding equity....
# 429  Constructed wealth variable, including equity....
# 430  The values for this variable represent the 202...
# 431  This variable provides a means of identifying ...
# 432  Note that these relationships are those to the...
#
#                                              LIST_CODE     STANDARDIZED_LABEL
# 0    {'CODE': {'VALUE': '1', 'TEXT': 'Release numbe...         release_number
# 1    {'CODE': [{'VALUE': '1 - 2,930', 'TEXT': 'Memb...  1968_interview_number
# 2    {'CODE': [{'VALUE': '1 - 19', 'TEXT': 'Individ...          person_number
# 3    {'CODE': [{'VALUE': '1', 'TEXT': 'Release numb...         release_number
# 4    {'CODE': {'VALUE': '1 - 7,457', 'TEXT': 'Inter...    family_interview_id
# ..                                                 ...                    ...
# 428  {'CODE': [{'VALUE': '-99,999,997 - -1', 'TEXT'...       wealth_wo_equity
# 429  {'CODE': [{'VALUE': '-99,999,997 - -1', 'TEXT'...     wealth_with_equity
# 430  {'CODE': [{'VALUE': '1 - 9,614', 'TEXT': '2021...  2021_interview_number
# 431  {'CODE': [{'VALUE': '1 - 20', 'TEXT': 'Individ...        sequence_number
# 432  {'CODE': [{'VALUE': '10', 'TEXT': 'Reference P...         relation_to_rp
#
# [433 rows x 8 columns]

# %%
codebook_df.STANDARDIZED_LABEL.unique()
# Out:
# array(['release_number', '1968_interview_number', 'person_number',
#        'family_interview_id', 'psid_state_of_residence_code', 'age',
#        'sex', 'number_of_children_in_fu', '1968_family_identifier',
#        'marital_status', 'health_status', 'race', 'religion',
#        'wtr_donated', 'wtr_donated_to_religious_org',
#        'amt_of_religious_donations', 'wtr_donated_to_combo_purpose_org',
#        'amt_of_combo_donations', 'wtr_donated_to_org_for_needy',
#        'amt_of_needy_donations', 'wtr_donated_to_health_org',
#        'amt_of_health_donations', 'wtr_donated_to_edu_org',
#        'amt_of_edu_donations', 't7a_wtr_donated_to_youth/family_organztn',
#        't7b_wtr_donatd_to_arts/cultr/ethnic_assn',
#        't7c_wtr_donatd_to_neighborhood/community',
#        't7d_wtr_donated_to_environmental_org',
#        't7e_wtr_donatd_to_intrnat_aid/wrld_peace',
#        't7f_wtr_donated_to_other_charity', 'amt_of_other_donations',
#        'total_family_social_security_income-2000', 'total_family_income',
#        'wealth_wo_equity', 'wealth_with_equity', '2001_interview_number',
#        'sequence_number', 'relation_to_rp', 'wtr_donated_to_youth_org',
#        'amt_of_youth_donations', 'wtr_donated_to_cultural_org',
#        'amt_of_cultural_donations', 'wtr_donated_to_community_org',
#        'amt_of_community_donations', 'wtr_donated_to_env_org',
#        'amt_of_env_donations', 'wtr_donated_intl/peace_org',
#        'wtr_donated_to_other', '2003_interview_number',
#        'm52k2_wtr_donated_$25_or_more', '2005_interview_number',
#        '2007_interview_number', '2009_interview_number',
#        '2011_interview_number', '2013_interview_number',
#        '2015_interview_number', '2017_interview_number',
#        '2019_interview_number', 'mgroup1_wtr_donate_combo/needy/med/intl',
#        'mgroup2_wtr_donate_educ/youth/cultr/envr',
#        'mcovid1_wtr_donate_to_help_re_pandemic',
#        'mcovid2_wtr_pandemic_donations_crowdfund',
#        'mcovid3_largest_crowdfund_donation_to',
#        'mcovid4_dollar_amt_pandemic_donations', '2021_interview_number'],
#       dtype=object)

# %%
code_mapping_dict_year = codebook_df.set_index("NAME").YEAR.to_dict()
code_mapping_dict_stdlab = codebook_df.set_index("NAME").STANDARDIZED_LABEL.to_dict()

# %% [markdown]
# # Wrangle .csv for analysis

# %%
# This line does NOT work because the .xlsx is encoded with "synchVertical" rather than "syncVertical",
# and oepnpyxl does not support synchVertical.
# Current solution: use local MS Excel to export data manually to a .csv

# psid_raw = pd.read_excel("../data/psid/J321540.xlsx", sheet_name="Data")

psid_raw = pd.read_csv("../data/psid/J322088.csv")
psid_raw
# Out:
#        ER30000  ER30001  ER30002  ER17001  ER17002  ER17004  ER17013  ER17014  \
# 0            1        4        3      7.0     96.0     41.0     49.0      1.0
# 1            1        4        4      7.0   5987.0     41.0     47.0      2.0
# 2            1        4        6      7.0   5599.0     15.0     43.0      1.0
# 3            1        4        7      7.0   7091.0     41.0     41.0      2.0
# 4            1        4        8      7.0   5964.0     41.0     36.0      1.0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 17802        1     6872      172      7.0   5477.0     12.0     39.0      1.0
# 17803        1     6872      174      7.0   5477.0     12.0     39.0      1.0
# 17804        1     6872      180      7.0   5477.0     12.0     39.0      1.0
# 17805        1     6872      182      7.0   3616.0     12.0     44.0      1.0
# 17806        1     6872      183      7.0   3616.0     12.0     44.0      1.0
#
#        ER17016  ER17022  ...  ER81406  ER81407  ER81414  ER81416   ER81775  \
# 0          1.0      4.0  ...      NaN      NaN      NaN      NaN       NaN
# 1          0.0      4.0  ...      NaN      NaN      NaN      NaN       NaN
# 2          0.0      4.0  ...      0.0      0.0      5.0      0.0   51560.0
# 3          1.0      4.0  ...      0.0      0.0      5.0      0.0   11720.0
# 4          3.0      4.0  ...      NaN      NaN      NaN      NaN       NaN
# ...        ...      ...  ...      ...      ...      ...      ...       ...
# 17802      4.0   6872.0  ...      NaN      NaN      NaN      NaN       NaN
# 17803      4.0   6872.0  ...      NaN      NaN      NaN      NaN       NaN
# 17804      4.0   6872.0  ...      NaN      NaN      NaN      NaN       NaN
# 17805      2.0   6872.0  ...      NaN      NaN      NaN      NaN       NaN
# 17806      2.0   6872.0  ...      0.0      0.0      5.0      0.0  160413.0
#
#        ER81836   ER81838  ER34901  ER34902  ER34903
# 0          NaN       NaN        0        0        0
# 1          NaN       NaN        0        0        0
# 2       2000.0    2000.0     7137       81       10
# 3      50000.0  230000.0     4890        1       10
# 4          NaN       NaN        0        0        0
# ...        ...       ...      ...      ...      ...
# 17802      NaN       NaN        0        0        0
# 17803      NaN       NaN        0        0        0
# 17804      NaN       NaN        0        0        0
# 17805      NaN       NaN        0        0        0
# 17806  63500.0  133500.0     5084        1       10
#
# [17807 rows x 433 columns]

# %%
# stash each year's income, contribution, etc. into same columns.
# Strategy: map each var's year and label in codebook and do a groupby

psid_year_grouped = psid_raw.groupby(by = code_mapping_dict_year, axis=1)
#psid_processed = pd.concat([psid_year.rename(columns=code_mapping_dict_stdlab).assign(YEAR = year) for year, psid_year in psid_year_grouped], axis=0)

# this cannot be used as is because families missing certain
# years of interviews are still kept in the original .csv with
# a value of nan in the year's variables
psid_year_grouped

# %%
psid_processed = pd.concat([psid_year.rename(columns=code_mapping_dict_stdlab).assign(year = year) for year, psid_year in psid_year_grouped], axis=1)

# %%
psid_processed
# Out:
#        release_number  1968_interview_number  person_number  year  \
# 0                   1                      4              3  1968
# 1                   1                      4              4  1968
# 2                   1                      4              6  1968
# 3                   1                      4              7  1968
# 4                   1                      4              8  1968
# ...               ...                    ...            ...   ...
# 17802               1                   6872            172  1968
# 17803               1                   6872            174  1968
# 17804               1                   6872            180  1968
# 17805               1                   6872            182  1968
# 17806               1                   6872            183  1968
#
#        release_number  family_interview_id  psid_state_of_residence_code  \
# 0                 7.0                 96.0                          41.0
# 1                 7.0               5987.0                          41.0
# 2                 7.0               5599.0                          15.0
# 3                 7.0               7091.0                          41.0
# 4                 7.0               5964.0                          41.0
# ...               ...                  ...                           ...
# 17802             7.0               5477.0                          12.0
# 17803             7.0               5477.0                          12.0
# 17804             7.0               5477.0                          12.0
# 17805             7.0               3616.0                          12.0
# 17806             7.0               3616.0                          12.0
#
#         age  sex  number_of_children_in_fu  ...  \
# 0      49.0  1.0                       1.0  ...
# 1      47.0  2.0                       0.0  ...
# 2      43.0  1.0                       0.0  ...
# 3      41.0  2.0                       1.0  ...
# 4      36.0  1.0                       3.0  ...
# ...     ...  ...                       ...  ...
# 17802  39.0  1.0                       4.0  ...
# 17803  39.0  1.0                       4.0  ...
# 17804  39.0  1.0                       4.0  ...
# 17805  44.0  1.0                       2.0  ...
# 17806  44.0  1.0                       2.0  ...
#
#        mcovid4_dollar_amt_pandemic_donations  wtr_donated_to_other  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
# 2                                        0.0                   5.0
# 3                                        0.0                   5.0
# 4                                        NaN                   NaN
# ...                                      ...                   ...
# 17802                                    NaN                   NaN
# 17803                                    NaN                   NaN
# 17804                                    NaN                   NaN
# 17805                                    NaN                   NaN
# 17806                                    0.0                   5.0
#
#        amt_of_other_donations  total_family_income  wealth_wo_equity  \
# 0                         NaN                  NaN               NaN
# 1                         NaN                  NaN               NaN
# 2                         0.0              51560.0            2000.0
# 3                         0.0              11720.0           50000.0
# 4                         NaN                  NaN               NaN
# ...                       ...                  ...               ...
# 17802                     NaN                  NaN               NaN
# 17803                     NaN                  NaN               NaN
# 17804                     NaN                  NaN               NaN
# 17805                     NaN                  NaN               NaN
# 17806                     0.0             160413.0           63500.0
#
#        wealth_with_equity  2021_interview_number  sequence_number  \
# 0                     NaN                      0                0
# 1                     NaN                      0                0
# 2                  2000.0                   7137               81
# 3                230000.0                   4890                1
# 4                     NaN                      0                0
# ...                   ...                    ...              ...
# 17802                 NaN                      0                0
# 17803                 NaN                      0                0
# 17804                 NaN                      0                0
# 17805                 NaN                      0                0
# 17806            133500.0                   5084                1
#
#        relation_to_rp  year
# 0                   0  2021
# 1                   0  2021
# 2                  10  2021
# 3                  10  2021
# 4                   0  2021
# ...               ...   ...
# 17802               0  2021
# 17803               0  2021
# 17804               0  2021
# 17805               0  2021
# 17806              10  2021
#
# [17807 rows x 445 columns]

# %%
psid_processed["individual_id"] = psid_processed["1968_interview_number"] * 1000 + psid_processed["person_number"]

# %%
psid_processed.columns.unique()
# Out:
# Index(['release_number', '1968_interview_number', 'person_number', 'year',
#        'family_interview_id', 'psid_state_of_residence_code', 'age', 'sex',
#        'number_of_children_in_fu', '1968_family_identifier', 'marital_status',
#        'health_status', 'race', 'religion', 'wtr_donated',
#        'wtr_donated_to_religious_org', 'amt_of_religious_donations',
#        'wtr_donated_to_combo_purpose_org', 'amt_of_combo_donations',
#        'wtr_donated_to_org_for_needy', 'amt_of_needy_donations',
#        'wtr_donated_to_health_org', 'amt_of_health_donations',
#        'wtr_donated_to_edu_org', 'amt_of_edu_donations',
#        't7a_wtr_donated_to_youth/family_organztn',
#        't7b_wtr_donatd_to_arts/cultr/ethnic_assn',
#        't7c_wtr_donatd_to_neighborhood/community',
#        't7d_wtr_donated_to_environmental_org',
#        't7e_wtr_donatd_to_intrnat_aid/wrld_peace',
#        't7f_wtr_donated_to_other_charity', 'amt_of_other_donations',
#        'total_family_social_security_income-2000', 'total_family_income',
#        'wealth_wo_equity', 'wealth_with_equity', '2001_interview_number',
#        'sequence_number', 'relation_to_rp', 'wtr_donated_to_youth_org',
#        'amt_of_youth_donations', 'wtr_donated_to_cultural_org',
#        'amt_of_cultural_donations', 'wtr_donated_to_community_org',
#        'amt_of_community_donations', 'wtr_donated_to_env_org',
#        'amt_of_env_donations', 'wtr_donated_intl/peace_org',
#        'wtr_donated_to_other', '2003_interview_number',
#        'm52k2_wtr_donated_$25_or_more', '2005_interview_number',
#        '2007_interview_number', '2009_interview_number',
#        '2011_interview_number', '2013_interview_number',
#        '2015_interview_number', '2017_interview_number',
#        '2019_interview_number', 'mgroup1_wtr_donate_combo/needy/med/intl',
#        'mgroup2_wtr_donate_educ/youth/cultr/envr',
#        'mcovid1_wtr_donate_to_help_re_pandemic',
#        'mcovid2_wtr_pandemic_donations_crowdfund',
#        'mcovid3_largest_crowdfund_donation_to',
#        'mcovid4_dollar_amt_pandemic_donations', '2021_interview_number',
#        'individual_id'],
#       dtype='object')

# %%
psid_sub = psid_processed.drop(columns = ['release_number', '1968_interview_number', 'person_number','2003_interview_number', '2005_interview_number',
       '2007_interview_number', '2009_interview_number',
       '2011_interview_number', '2013_interview_number',
       '2015_interview_number', '2017_interview_number',
       '2019_interview_number','2001_interview_number','2021_interview_number'])

# %%
psid_sub
# Out:
#        year  family_interview_id  psid_state_of_residence_code   age  sex  \
# 0      1968                 96.0                          41.0  49.0  1.0
# 1      1968               5987.0                          41.0  47.0  2.0
# 2      1968               5599.0                          15.0  43.0  1.0
# 3      1968               7091.0                          41.0  41.0  2.0
# 4      1968               5964.0                          41.0  36.0  1.0
# ...     ...                  ...                           ...   ...  ...
# 17802  1968               5477.0                          12.0  39.0  1.0
# 17803  1968               5477.0                          12.0  39.0  1.0
# 17804  1968               5477.0                          12.0  39.0  1.0
# 17805  1968               3616.0                          12.0  44.0  1.0
# 17806  1968               3616.0                          12.0  44.0  1.0
#
#        number_of_children_in_fu  1968_family_identifier  marital_status  \
# 0                           1.0                     4.0             1.0
# 1                           0.0                     4.0             4.0
# 2                           0.0                     4.0             4.0
# 3                           1.0                     4.0             4.0
# 4                           3.0                     4.0             1.0
# ...                         ...                     ...             ...
# 17802                       4.0                  6872.0             1.0
# 17803                       4.0                  6872.0             1.0
# 17804                       4.0                  6872.0             1.0
# 17805                       2.0                  6872.0             1.0
# 17806                       2.0                  6872.0             1.0
#
#        health_status  race  ...  mcovid4_dollar_amt_pandemic_donations  \
# 0                1.0   1.0  ...                                    NaN
# 1                3.0   1.0  ...                                    NaN
# 2                2.0   1.0  ...                                    0.0
# 3                2.0   1.0  ...                                    0.0
# 4                1.0   1.0  ...                                    NaN
# ...              ...   ...  ...                                    ...
# 17802            4.0   2.0  ...                                    NaN
# 17803            4.0   2.0  ...                                    NaN
# 17804            4.0   2.0  ...                                    NaN
# 17805            4.0   2.0  ...                                    NaN
# 17806            4.0   2.0  ...                                    0.0
#
#        wtr_donated_to_other  amt_of_other_donations  total_family_income  \
# 0                       NaN                     NaN                  NaN
# 1                       NaN                     NaN                  NaN
# 2                       5.0                     0.0              51560.0
# 3                       5.0                     0.0              11720.0
# 4                       NaN                     NaN                  NaN
# ...                     ...                     ...                  ...
# 17802                   NaN                     NaN                  NaN
# 17803                   NaN                     NaN                  NaN
# 17804                   NaN                     NaN                  NaN
# 17805                   NaN                     NaN                  NaN
# 17806                   5.0                     0.0             160413.0
#
#        wealth_wo_equity  wealth_with_equity  sequence_number  relation_to_rp  \
# 0                   NaN                 NaN                0               0
# 1                   NaN                 NaN                0               0
# 2                2000.0              2000.0               81              10
# 3               50000.0            230000.0                1              10
# 4                   NaN                 NaN                0               0
# ...                 ...                 ...              ...             ...
# 17802               NaN                 NaN                0               0
# 17803               NaN                 NaN                0               0
# 17804               NaN                 NaN                0               0
# 17805               NaN                 NaN                0               0
# 17806           63500.0            133500.0                1              10
#
#        year  individual_id
# 0      2021           4003
# 1      2021           4004
# 2      2021           4006
# 3      2021           4007
# 4      2021           4008
# ...     ...            ...
# 17802  2021        6872172
# 17803  2021        6872174
# 17804  2021        6872180
# 17805  2021        6872182
# 17806  2021        6872183
#
# [17807 rows x 421 columns]

# %% [markdown]
# ### Clean the 2021 data

# %%
psid_sub['wtr_donated_2021'] = np.where( ((psid_sub['mgroup1_wtr_donate_combo/needy/med/intl'] == 1) | (psid_sub['mgroup2_wtr_donate_educ/youth/cultr/envr'] == 1) | (psid_sub['mcovid1_wtr_donate_to_help_re_pandemic'] == 1)), 1, 5)
# Out:
# <ipython-input-26-858ea96b864b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   psid_sub['wtr_donated_2021'] = np.where( ((psid_sub['mgroup1_wtr_donate_combo/needy/med/intl'] == 1) | (psid_sub['mgroup2_wtr_donate_educ/youth/cultr/envr'] == 1) | (psid_sub['mcovid1_wtr_donate_to_help_re_pandemic'] == 1)), 1, 5)

# %%
psid_sub
# Out:
#        year  family_interview_id  psid_state_of_residence_code   age  sex  \
# 0      1968                 96.0                          41.0  49.0  1.0
# 1      1968               5987.0                          41.0  47.0  2.0
# 2      1968               5599.0                          15.0  43.0  1.0
# 3      1968               7091.0                          41.0  41.0  2.0
# 4      1968               5964.0                          41.0  36.0  1.0
# ...     ...                  ...                           ...   ...  ...
# 17802  1968               5477.0                          12.0  39.0  1.0
# 17803  1968               5477.0                          12.0  39.0  1.0
# 17804  1968               5477.0                          12.0  39.0  1.0
# 17805  1968               3616.0                          12.0  44.0  1.0
# 17806  1968               3616.0                          12.0  44.0  1.0
#
#        number_of_children_in_fu  1968_family_identifier  marital_status  \
# 0                           1.0                     4.0             1.0
# 1                           0.0                     4.0             4.0
# 2                           0.0                     4.0             4.0
# 3                           1.0                     4.0             4.0
# 4                           3.0                     4.0             1.0
# ...                         ...                     ...             ...
# 17802                       4.0                  6872.0             1.0
# 17803                       4.0                  6872.0             1.0
# 17804                       4.0                  6872.0             1.0
# 17805                       2.0                  6872.0             1.0
# 17806                       2.0                  6872.0             1.0
#
#        health_status  race  ...  wtr_donated_to_other  amt_of_other_donations  \
# 0                1.0   1.0  ...                   NaN                     NaN
# 1                3.0   1.0  ...                   NaN                     NaN
# 2                2.0   1.0  ...                   5.0                     0.0
# 3                2.0   1.0  ...                   5.0                     0.0
# 4                1.0   1.0  ...                   NaN                     NaN
# ...              ...   ...  ...                   ...                     ...
# 17802            4.0   2.0  ...                   NaN                     NaN
# 17803            4.0   2.0  ...                   NaN                     NaN
# 17804            4.0   2.0  ...                   NaN                     NaN
# 17805            4.0   2.0  ...                   NaN                     NaN
# 17806            4.0   2.0  ...                   5.0                     0.0
#
#        total_family_income  wealth_wo_equity  wealth_with_equity  \
# 0                      NaN               NaN                 NaN
# 1                      NaN               NaN                 NaN
# 2                  51560.0            2000.0              2000.0
# 3                  11720.0           50000.0            230000.0
# 4                      NaN               NaN                 NaN
# ...                    ...               ...                 ...
# 17802                  NaN               NaN                 NaN
# 17803                  NaN               NaN                 NaN
# 17804                  NaN               NaN                 NaN
# 17805                  NaN               NaN                 NaN
# 17806             160413.0           63500.0            133500.0
#
#        sequence_number  relation_to_rp  year  individual_id  wtr_donated_2021
# 0                    0               0  2021           4003                 5
# 1                    0               0  2021           4004                 5
# 2                   81              10  2021           4006                 5
# 3                    1              10  2021           4007                 5
# 4                    0               0  2021           4008                 5
# ...                ...             ...   ...            ...               ...
# 17802                0               0  2021        6872172                 5
# 17803                0               0  2021        6872174                 5
# 17804                0               0  2021        6872180                 5
# 17805                0               0  2021        6872182                 5
# 17806                1              10  2021        6872183                 5
#
# [17807 rows x 422 columns]

# %%
psid_sub = psid_sub.drop(columns = ['mgroup1_wtr_donate_combo/needy/med/intl', 'mgroup2_wtr_donate_educ/youth/cultr/envr', 'total_family_social_security_income-2000', 'm52k2_wtr_donated_$25_or_more'])

# %%
reg_raw = psid_processed.drop(columns = ['release_number', '1968_interview_number', 'person_number','wtr_donated_to_religious_org',
       'amt_of_religious_donations', 'wtr_donated_to_combo_purpose_org',
       'amt_of_combo_donations', 'wtr_donated_to_org_for_needy',
       'amt_of_needy_donations','wtr_donated_to_edu_org',
       'amt_of_edu_donations', 'amt_of_other_donations','2003_interview_number', '2005_interview_number',
       '2007_interview_number', '2009_interview_number',
       '2011_interview_number', '2013_interview_number',
       '2015_interview_number', '2017_interview_number',
       '2019_interview_number','2001_interview_number','wtr_donated_to_youth_org',
       'amt_of_youth_donations', 'wtr_donated_to_cultural_org',
       'amt_of_cultural_donations', 'wtr_donated_to_community_org',
       'amt_of_community_donations', 'wtr_donated_to_env_org',
       'amt_of_env_donations', 'wtr_donated_intl/peace_org',
       'amt_of_intl/peace_donations', 'wtr_donated_to_other'])

# %%
reg_raw.columns.unique()
# Out:
# Index(['year', 'family_interview_id', 'psid_state_of_residence_code',
#        'family_composition_change', 'age', 'sex', 'number_of_children_in_fu',
#        '1968_family_identifier', 'marital_status', 'health_status', 'race',
#        'religion', 'wtr_donated', 'wtr_donated_to_health_org',
#        'amt_of_health_donations', 'total_family_income', 'wealth_wo_equity',
#        'wealth_with_equity', 'sequence_number', 'relation_to_rp',
#        'individual_id'],
#       dtype='object')

# %%
for i in psid_processed_sub.columns.unique():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2bd0f827cc0d> in <module>
# ----> 1 for i in psid_processed_sub.columns.unique():
#       2     print(i)
#
# NameError: name 'psid_processed_sub' is not defined

# %% [markdown]
# ## Wide to Long

# %%
reg_raw.to_csv("reg_raw.csv", index = False)

# %%
#test = psid_processed_sub.dropna()
test = reg_raw.dropna()

# %%
test
# Out:
#        year  family_interview_id  psid_state_of_residence_code  \
# 2      1968               5599.0                          15.0
# 5      1968                285.0                          41.0
# 11     1968                 96.0                          41.0
# 13     1968                285.0                          41.0
# 15     1968               5964.0                          41.0
# ...     ...                  ...                           ...
# 17030  1968               3616.0                          12.0
# 17031  1968               5477.0                          12.0
# 17032  1968               3616.0                          12.0
# 17035  1968               5477.0                          12.0
# 17038  1968               3616.0                          12.0
#
#        family_composition_change   age  sex  number_of_children_in_fu  \
# 2                            0.0  43.0  1.0                       0.0
# 5                            4.0  28.0  1.0                       2.0
# 11                           1.0  49.0  1.0                       1.0
# 13                           4.0  28.0  1.0                       2.0
# 15                           1.0  36.0  1.0                       3.0
# ...                          ...   ...  ...                       ...
# 17030                        0.0  44.0  1.0                       2.0
# 17031                        0.0  39.0  1.0                       4.0
# 17032                        0.0  44.0  1.0                       2.0
# 17035                        0.0  39.0  1.0                       4.0
# 17038                        0.0  44.0  1.0                       2.0
#
#        1968_family_identifier  marital_status  health_status  ...  \
# 2                         4.0             4.0            2.0  ...
# 5                         4.0             1.0            1.0  ...
# 11                        4.0             1.0            1.0  ...
# 13                        4.0             1.0            1.0  ...
# 15                        4.0             1.0            1.0  ...
# ...                       ...             ...            ...  ...
# 17030                  6872.0             1.0            4.0  ...
# 17031                  6872.0             1.0            4.0  ...
# 17032                  6872.0             1.0            4.0  ...
# 17035                  6872.0             1.0            4.0  ...
# 17038                  6872.0             1.0            4.0  ...
#
#        wtr_donated  wtr_donated_to_health_org  amt_of_health_donations  \
# 2              1.0                        5.0                      0.0
# 5              5.0                        0.0                      0.0
# 11             5.0                        0.0                      0.0
# 13             5.0                        0.0                      0.0
# 15             5.0                        0.0                      0.0
# ...            ...                        ...                      ...
# 17030          5.0                        0.0                      0.0
# 17031          5.0                        0.0                      0.0
# 17032          5.0                        0.0                      0.0
# 17035          5.0                        0.0                      0.0
# 17038          5.0                        0.0                      0.0
#
#        total_family_income  wealth_wo_equity  wealth_with_equity  \
# 2                  11028.0            1200.0              1200.0
# 5                   9380.0               0.0                 0.0
# 11                 31000.0           14000.0             14000.0
# 13                 65000.0               0.0             20000.0
# 15                 72200.0           15200.0             15200.0
# ...                    ...               ...                 ...
# 17030               7518.0            1000.0              1000.0
# 17031             103080.0            3900.0             78900.0
# 17032              38000.0           34000.0             34000.0
# 17035              97000.0          225600.0            255600.0
# 17038             147800.0          120700.0            200700.0
#
#        sequence_number  relation_to_rp  year  individual_id
# 2                    1              10  2019           4006
# 5                    1              10  2019           4031
# 11                   1              10  2019           4039
# 13                   2              22  2019           4041
# 15                   2              20  2019           4180
# ...                ...             ...   ...            ...
# 17030                1              10  2019        6872002
# 17031                1              10  2019        6872003
# 17032                1              10  2019        6872031
# 17035                1              10  2019        6872174
# 17038                1              10  2019        6872183
#
# [8874 rows x 202 columns]

# %%
test = test.drop(columns = ["release_number", "1968_interview_number", "person_number", '2001_interview_number', '2003_interview_number',
       '2005_interview_number', '2007_interview_number',
       '2009_interview_number', '2011_interview_number',
       '2013_interview_number', '2015_interview_number',
       '2017_interview_number', '2019_interview_number'])

# %%
test.columns.unique()
# Out:
# Index(['year', 'family_interview_id', 'psid_state_of_residence_code',
#        'family_composition_change', 'age', 'sex', 'number_of_children_in_fu',
#        '1968_family_identifier', 'marital_status', 'health_status', 'race',
#        'religion', 'wtr_donated', 'wtr_donated_to_health_org',
#        'amt_of_health_donations', 'total_family_income', 'wealth_wo_equity',
#        'wealth_with_equity', 'sequence_number', 'relation_to_rp',
#        'individual_id'],
#       dtype='object')

# %%
cols = list(test.columns)
len(cols)
y = 2001
for i in range(1, len(cols) - 1, 20):
    for j in range(i, i + 20):
        cols[j] += '-' + str(y)
    y += 2

# %%
cols
# Out:
# ['year',
#  'family_interview_id-2001',
#  'psid_state_of_residence_code-2001',
#  'family_composition_change-2001',
#  'age-2001',
#  'sex-2001',
#  'number_of_children_in_fu-2001',
#  '1968_family_identifier-2001',
#  'marital_status-2001',
#  'health_status-2001',
#  'race-2001',
#  'religion-2001',
#  'wtr_donated-2001',
#  'wtr_donated_to_health_org-2001',
#  'amt_of_health_donations-2001',
#  'total_family_income-2001',
#  'wealth_wo_equity-2001',
#  'wealth_with_equity-2001',
#  'sequence_number-2001',
#  'relation_to_rp-2001',
#  'year-2001',
#  'family_interview_id-2003',
#  'psid_state_of_residence_code-2003',
#  'family_composition_change-2003',
#  '1968_family_identifier-2003',
#  'age-2003',
#  'sex-2003',
#  'number_of_children_in_fu-2003',
#  'marital_status-2003',
#  'health_status-2003',
#  'race-2003',
#  'religion-2003',
#  'wtr_donated-2003',
#  'wtr_donated_to_health_org-2003',
#  'amt_of_health_donations-2003',
#  'total_family_income-2003',
#  'wealth_wo_equity-2003',
#  'wealth_with_equity-2003',
#  'sequence_number-2003',
#  'relation_to_rp-2003',
#  'year-2003',
#  'family_interview_id-2005',
#  'psid_state_of_residence_code-2005',
#  'family_composition_change-2005',
#  '1968_family_identifier-2005',
#  'age-2005',
#  'sex-2005',
#  'number_of_children_in_fu-2005',
#  'marital_status-2005',
#  'health_status-2005',
#  'race-2005',
#  'religion-2005',
#  'wtr_donated-2005',
#  'wtr_donated_to_health_org-2005',
#  'amt_of_health_donations-2005',
#  'total_family_income-2005',
#  'wealth_wo_equity-2005',
#  'wealth_with_equity-2005',
#  'sequence_number-2005',
#  'relation_to_rp-2005',
#  'year-2005',
#  'family_interview_id-2007',
#  'psid_state_of_residence_code-2007',
#  'family_composition_change-2007',
#  '1968_family_identifier-2007',
#  'age-2007',
#  'sex-2007',
#  'number_of_children_in_fu-2007',
#  'marital_status-2007',
#  'health_status-2007',
#  'race-2007',
#  'religion-2007',
#  'wtr_donated-2007',
#  'wtr_donated_to_health_org-2007',
#  'amt_of_health_donations-2007',
#  'total_family_income-2007',
#  'wealth_wo_equity-2007',
#  'wealth_with_equity-2007',
#  'sequence_number-2007',
#  'relation_to_rp-2007',
#  'year-2007',
#  'family_interview_id-2009',
#  'psid_state_of_residence_code-2009',
#  'family_composition_change-2009',
#  '1968_family_identifier-2009',
#  'age-2009',
#  'sex-2009',
#  'number_of_children_in_fu-2009',
#  'marital_status-2009',
#  'health_status-2009',
#  'race-2009',
#  'religion-2009',
#  'wtr_donated-2009',
#  'wtr_donated_to_health_org-2009',
#  'amt_of_health_donations-2009',
#  'total_family_income-2009',
#  'wealth_wo_equity-2009',
#  'wealth_with_equity-2009',
#  'sequence_number-2009',
#  'relation_to_rp-2009',
#  'year-2009',
#  'family_interview_id-2011',
#  'psid_state_of_residence_code-2011',
#  'family_composition_change-2011',
#  '1968_family_identifier-2011',
#  'age-2011',
#  'sex-2011',
#  'number_of_children_in_fu-2011',
#  'marital_status-2011',
#  'health_status-2011',
#  'race-2011',
#  'religion-2011',
#  'wtr_donated-2011',
#  'wtr_donated_to_health_org-2011',
#  'amt_of_health_donations-2011',
#  'total_family_income-2011',
#  'wealth_wo_equity-2011',
#  'wealth_with_equity-2011',
#  'sequence_number-2011',
#  'relation_to_rp-2011',
#  'year-2011',
#  'family_interview_id-2013',
#  'psid_state_of_residence_code-2013',
#  'family_composition_change-2013',
#  '1968_family_identifier-2013',
#  'age-2013',
#  'sex-2013',
#  'number_of_children_in_fu-2013',
#  'marital_status-2013',
#  'health_status-2013',
#  'race-2013',
#  'religion-2013',
#  'wtr_donated-2013',
#  'wtr_donated_to_health_org-2013',
#  'amt_of_health_donations-2013',
#  'total_family_income-2013',
#  'wealth_wo_equity-2013',
#  'wealth_with_equity-2013',
#  'sequence_number-2013',
#  'relation_to_rp-2013',
#  'year-2013',
#  'family_interview_id-2015',
#  'psid_state_of_residence_code-2015',
#  'family_composition_change-2015',
#  '1968_family_identifier-2015',
#  'age-2015',
#  'sex-2015',
#  'number_of_children_in_fu-2015',
#  'marital_status-2015',
#  'health_status-2015',
#  'race-2015',
#  'religion-2015',
#  'wtr_donated-2015',
#  'wtr_donated_to_health_org-2015',
#  'amt_of_health_donations-2015',
#  'total_family_income-2015',
#  'wealth_wo_equity-2015',
#  'wealth_with_equity-2015',
#  'sequence_number-2015',
#  'relation_to_rp-2015',
#  'year-2015',
#  'family_interview_id-2017',
#  'psid_state_of_residence_code-2017',
#  'family_composition_change-2017',
#  '1968_family_identifier-2017',
#  'age-2017',
#  'sex-2017',
#  'number_of_children_in_fu-2017',
#  'marital_status-2017',
#  'health_status-2017',
#  'race-2017',
#  'religion-2017',
#  'wtr_donated-2017',
#  'wtr_donated_to_health_org-2017',
#  'amt_of_health_donations-2017',
#  'total_family_income-2017',
#  'wealth_wo_equity-2017',
#  'wealth_with_equity-2017',
#  'sequence_number-2017',
#  'relation_to_rp-2017',
#  'year-2017',
#  'family_interview_id-2019',
#  'psid_state_of_residence_code-2019',
#  'family_composition_change-2019',
#  '1968_family_identifier-2019',
#  'age-2019',
#  'sex-2019',
#  'number_of_children_in_fu-2019',
#  'marital_status-2019',
#  'health_status-2019',
#  'race-2019',
#  'religion-2019',
#  'wtr_donated-2019',
#  'wtr_donated_to_health_org-2019',
#  'amt_of_health_donations-2019',
#  'total_family_income-2019',
#  'wealth_wo_equity-2019',
#  'wealth_with_equity-2019',
#  'sequence_number-2019',
#  'relation_to_rp-2019',
#  'year-2019',
#  'individual_id']

# %%
test.columns = cols

# %%
del test["year"]

# %%
test
# Out:
#        family_interview_id-2001  psid_state_of_residence_code-2001  \
# 2                        5599.0                               15.0
# 5                         285.0                               41.0
# 11                         96.0                               41.0
# 13                        285.0                               41.0
# 15                       5964.0                               41.0
# ...                         ...                                ...
# 17030                    3616.0                               12.0
# 17031                    5477.0                               12.0
# 17032                    3616.0                               12.0
# 17035                    5477.0                               12.0
# 17038                    3616.0                               12.0
#
#        family_composition_change-2001  age-2001  sex-2001  \
# 2                                 0.0      43.0       1.0
# 5                                 4.0      28.0       1.0
# 11                                1.0      49.0       1.0
# 13                                4.0      28.0       1.0
# 15                                1.0      36.0       1.0
# ...                               ...       ...       ...
# 17030                             0.0      44.0       1.0
# 17031                             0.0      39.0       1.0
# 17032                             0.0      44.0       1.0
# 17035                             0.0      39.0       1.0
# 17038                             0.0      44.0       1.0
#
#        number_of_children_in_fu-2001  1968_family_identifier-2001  \
# 2                                0.0                          4.0
# 5                                2.0                          4.0
# 11                               1.0                          4.0
# 13                               2.0                          4.0
# 15                               3.0                          4.0
# ...                              ...                          ...
# 17030                            2.0                       6872.0
# 17031                            4.0                       6872.0
# 17032                            2.0                       6872.0
# 17035                            4.0                       6872.0
# 17038                            2.0                       6872.0
#
#        marital_status-2001  health_status-2001  race-2001  ...  \
# 2                      4.0                 2.0        1.0  ...
# 5                      1.0                 1.0        1.0  ...
# 11                     1.0                 1.0        1.0  ...
# 13                     1.0                 1.0        1.0  ...
# 15                     1.0                 1.0        1.0  ...
# ...                    ...                 ...        ...  ...
# 17030                  1.0                 4.0        2.0  ...
# 17031                  1.0                 4.0        2.0  ...
# 17032                  1.0                 4.0        2.0  ...
# 17035                  1.0                 4.0        2.0  ...
# 17038                  1.0                 4.0        2.0  ...
#
#        wtr_donated-2019  wtr_donated_to_health_org-2019  \
# 2                   1.0                             5.0
# 5                   5.0                             0.0
# 11                  5.0                             0.0
# 13                  5.0                             0.0
# 15                  5.0                             0.0
# ...                 ...                             ...
# 17030               5.0                             0.0
# 17031               5.0                             0.0
# 17032               5.0                             0.0
# 17035               5.0                             0.0
# 17038               5.0                             0.0
#
#        amt_of_health_donations-2019  total_family_income-2019  \
# 2                               0.0                   11028.0
# 5                               0.0                    9380.0
# 11                              0.0                   31000.0
# 13                              0.0                   65000.0
# 15                              0.0                   72200.0
# ...                             ...                       ...
# 17030                           0.0                    7518.0
# 17031                           0.0                  103080.0
# 17032                           0.0                   38000.0
# 17035                           0.0                   97000.0
# 17038                           0.0                  147800.0
#
#        wealth_wo_equity-2019  wealth_with_equity-2019  sequence_number-2019  \
# 2                     1200.0                   1200.0                     1
# 5                        0.0                      0.0                     1
# 11                   14000.0                  14000.0                     1
# 13                       0.0                  20000.0                     2
# 15                   15200.0                  15200.0                     2
# ...                      ...                      ...                   ...
# 17030                 1000.0                   1000.0                     1
# 17031                 3900.0                  78900.0                     1
# 17032                34000.0                  34000.0                     1
# 17035               225600.0                 255600.0                     1
# 17038               120700.0                 200700.0                     1
#
#        relation_to_rp-2019  year-2019 individual_id
# 2                       10       2019          4006
# 5                       10       2019          4031
# 11                      10       2019          4039
# 13                      22       2019          4041
# 15                      20       2019          4180
# ...                    ...        ...           ...
# 17030                   10       2019       6872002
# 17031                   10       2019       6872003
# 17032                   10       2019       6872031
# 17035                   10       2019       6872174
# 17038                   10       2019       6872183
#
# [8874 rows x 201 columns]

# %%
tutorial = test[(test['sequence_number-2001'] >= 1) & (test['sequence_number-2001'] <= 20) & (test['relation_to_rp-2001'] == 10) & (test['sequence_number-2001'] == 1) &
                (test['sequence_number-2003'] >= 1) & (test['sequence_number-2003'] <= 20) & (test['relation_to_rp-2003'] == 10) & (test['sequence_number-2003'] == 1) &
                (test['sequence_number-2005'] >= 1) & (test['sequence_number-2005'] <= 20) & (test['relation_to_rp-2005'] == 10) & (test['sequence_number-2005'] == 1) &
                (test['sequence_number-2007'] >= 1) & (test['sequence_number-2007'] <= 20) & (test['relation_to_rp-2007'] == 10) & (test['sequence_number-2007'] == 1) &
                (test['sequence_number-2009'] >= 1) & (test['sequence_number-2009'] <= 20) & (test['relation_to_rp-2009'] == 10) & (test['sequence_number-2009'] == 1) &
                (test['sequence_number-2011'] >= 1) & (test['sequence_number-2011'] <= 20) & (test['relation_to_rp-2011'] == 10) & (test['sequence_number-2011'] == 1) &
                (test['sequence_number-2013'] >= 1) & (test['sequence_number-2013'] <= 20) & (test['relation_to_rp-2013'] == 10) & (test['sequence_number-2013'] == 1) &
                (test['sequence_number-2015'] >= 1) & (test['sequence_number-2015'] <= 20) & (test['relation_to_rp-2015'] == 10) & (test['sequence_number-2015'] == 1) &
                (test['sequence_number-2017'] >= 1) & (test['sequence_number-2017'] <= 20) & (test['relation_to_rp-2017'] == 10) & (test['sequence_number-2017'] == 1) &
                (test['sequence_number-2019'] >= 1) & (test['sequence_number-2019'] <= 20) & (test['relation_to_rp-2019'] == 10) & (test['sequence_number-2019'] == 1)]

# %%
tutorial
# Out:
#        family_interview_id-2001  psid_state_of_residence_code-2001  \
# 32                       1448.0                               41.0
# 47                       6438.0                               26.0
# 52                        263.0                               12.0
# 55                       3133.0                               34.0
# 56                       3198.0                               34.0
# ...                         ...                                ...
# 16987                    4711.0                                4.0
# 17002                    4961.0                               19.0
# 17008                    5956.0                               42.0
# 17016                    5955.0                               42.0
# 17031                    5477.0                               12.0
#
#        family_composition_change-2001  age-2001  sex-2001  \
# 32                                0.0      38.0       1.0
# 47                                1.0      46.0       1.0
# 52                                1.0      56.0       1.0
# 55                                1.0      47.0       1.0
# 56                                0.0      45.0       2.0
# ...                               ...       ...       ...
# 16987                             0.0      42.0       1.0
# 17002                             1.0      42.0       2.0
# 17008                             0.0      47.0       2.0
# 17016                             4.0      24.0       1.0
# 17031                             0.0      39.0       1.0
#
#        number_of_children_in_fu-2001  1968_family_identifier-2001  \
# 32                               2.0                          5.0
# 47                               1.0                          6.0
# 52                               0.0                          6.0
# 55                               0.0                          7.0
# 56                               0.0                          7.0
# ...                              ...                          ...
# 16987                            1.0                       6854.0
# 17002                            1.0                       6862.0
# 17008                            1.0                       6864.0
# 17016                            0.0                       6864.0
# 17031                            4.0                       6872.0
#
#        marital_status-2001  health_status-2001  race-2001  ...  \
# 32                     1.0                 2.0        1.0  ...
# 47                     1.0                 1.0        1.0  ...
# 52                     1.0                 1.0        1.0  ...
# 55                     1.0                 5.0        1.0  ...
# 56                     4.0                 3.0        1.0  ...
# ...                    ...                 ...        ...  ...
# 16987                  2.0                 3.0        2.0  ...
# 17002                  1.0                 3.0        2.0  ...
# 17008                  4.0                 2.0        2.0  ...
# 17016                  2.0                 2.0        2.0  ...
# 17031                  1.0                 4.0        2.0  ...
#
#        wtr_donated-2019  wtr_donated_to_health_org-2019  \
# 32                  1.0                             5.0
# 47                  1.0                             5.0
# 52                  5.0                             0.0
# 55                  5.0                             0.0
# 56                  5.0                             0.0
# ...                 ...                             ...
# 16987               5.0                             0.0
# 17002               1.0                             5.0
# 17008               5.0                             0.0
# 17016               5.0                             0.0
# 17031               5.0                             0.0
#
#        amt_of_health_donations-2019  total_family_income-2019  \
# 32                              0.0                   67000.0
# 47                              0.0                  243000.0
# 52                              0.0                   29100.0
# 55                              0.0                    7596.0
# 56                              0.0                   23928.0
# ...                             ...                       ...
# 16987                           0.0                   46772.0
# 17002                           0.0                   65000.0
# 17008                           0.0                   29000.0
# 17016                           0.0                   56000.0
# 17031                           0.0                  103080.0
#
#        wealth_wo_equity-2019  wealth_with_equity-2019  sequence_number-2019  \
# 32                  124000.0                 324000.0                     1
# 47                 2550000.0                2700000.0                     1
# 52                   40000.0                 155000.0                     1
# 55                    7020.0                   7020.0                     1
# 56                       0.0                      0.0                     1
# ...                      ...                      ...                   ...
# 16987                 5000.0                   5000.0                     1
# 17002                40000.0                  40000.0                     1
# 17008                 9000.0                   9000.0                     1
# 17016               100000.0                 140000.0                     1
# 17031                 3900.0                  78900.0                     1
#
#        relation_to_rp-2019  year-2019 individual_id
# 32                      10       2019          5003
# 47                      10       2019          6006
# 52                      10       2019          6170
# 55                      10       2019          7003
# 56                      10       2019          7004
# ...                    ...        ...           ...
# 16987                   10       2019       6854004
# 17002                   10       2019       6862008
# 17008                   10       2019       6864002
# 17016                   10       2019       6864177
# 17031                   10       2019       6872003
#
# [3051 rows x 201 columns]

# %%
tutorial.to_csv("tutorial.csv", index = False)

# %%
same = test[test['family_composition_change-2003'].isin([0, 1, 2]) &
            test['family_composition_change-2005'].isin([0, 1, 2]) &
            test['family_composition_change-2007'].isin([0, 1, 2]) &
            test['family_composition_change-2009'].isin([0, 1, 2]) &
            test['family_composition_change-2011'].isin([0, 1, 2]) &
            test['family_composition_change-2013'].isin([0, 1, 2]) &
            test['family_composition_change-2015'].isin([0, 1, 2]) &
            test['family_composition_change-2017'].isin([0, 1, 2]) &
            test['family_composition_change-2019'].isin([0, 1, 2])]
same
# Out:
#        family_interview_id-2001  psid_state_of_residence_code-2001  \
# 32                       1448.0                               41.0
# 47                       6438.0                               26.0
# 52                        263.0                               12.0
# 55                       3133.0                               34.0
# 56                       3198.0                               34.0
# ...                         ...                                ...
# 16987                    4711.0                                4.0
# 17002                    4961.0                               19.0
# 17008                    5956.0                               42.0
# 17016                    5955.0                               42.0
# 17031                    5477.0                               12.0
#
#        family_composition_change-2001  age-2001  sex-2001  \
# 32                                0.0      38.0       1.0
# 47                                1.0      46.0       1.0
# 52                                1.0      56.0       1.0
# 55                                1.0      47.0       1.0
# 56                                0.0      45.0       2.0
# ...                               ...       ...       ...
# 16987                             0.0      42.0       1.0
# 17002                             1.0      42.0       2.0
# 17008                             0.0      47.0       2.0
# 17016                             4.0      24.0       1.0
# 17031                             0.0      39.0       1.0
#
#        number_of_children_in_fu-2001  1968_family_identifier-2001  \
# 32                               2.0                          5.0
# 47                               1.0                          6.0
# 52                               0.0                          6.0
# 55                               0.0                          7.0
# 56                               0.0                          7.0
# ...                              ...                          ...
# 16987                            1.0                       6854.0
# 17002                            1.0                       6862.0
# 17008                            1.0                       6864.0
# 17016                            0.0                       6864.0
# 17031                            4.0                       6872.0
#
#        marital_status-2001  health_status-2001  race-2001  ...  \
# 32                     1.0                 2.0        1.0  ...
# 47                     1.0                 1.0        1.0  ...
# 52                     1.0                 1.0        1.0  ...
# 55                     1.0                 5.0        1.0  ...
# 56                     4.0                 3.0        1.0  ...
# ...                    ...                 ...        ...  ...
# 16987                  2.0                 3.0        2.0  ...
# 17002                  1.0                 3.0        2.0  ...
# 17008                  4.0                 2.0        2.0  ...
# 17016                  2.0                 2.0        2.0  ...
# 17031                  1.0                 4.0        2.0  ...
#
#        wtr_donated-2019  wtr_donated_to_health_org-2019  \
# 32                  1.0                             5.0
# 47                  1.0                             5.0
# 52                  5.0                             0.0
# 55                  5.0                             0.0
# 56                  5.0                             0.0
# ...                 ...                             ...
# 16987               5.0                             0.0
# 17002               1.0                             5.0
# 17008               5.0                             0.0
# 17016               5.0                             0.0
# 17031               5.0                             0.0
#
#        amt_of_health_donations-2019  total_family_income-2019  \
# 32                              0.0                   67000.0
# 47                              0.0                  243000.0
# 52                              0.0                   29100.0
# 55                              0.0                    7596.0
# 56                              0.0                   23928.0
# ...                             ...                       ...
# 16987                           0.0                   46772.0
# 17002                           0.0                   65000.0
# 17008                           0.0                   29000.0
# 17016                           0.0                   56000.0
# 17031                           0.0                  103080.0
#
#        wealth_wo_equity-2019  wealth_with_equity-2019  sequence_number-2019  \
# 32                  124000.0                 324000.0                     1
# 47                 2550000.0                2700000.0                     1
# 52                   40000.0                 155000.0                     1
# 55                    7020.0                   7020.0                     1
# 56                       0.0                      0.0                     1
# ...                      ...                      ...                   ...
# 16987                 5000.0                   5000.0                     1
# 17002                40000.0                  40000.0                     1
# 17008                 9000.0                   9000.0                     1
# 17016               100000.0                 140000.0                     1
# 17031                 3900.0                  78900.0                     1
#
#        relation_to_rp-2019  year-2019 individual_id
# 32                      10       2019          5003
# 47                      10       2019          6006
# 52                      10       2019          6170
# 55                      10       2019          7003
# 56                      10       2019          7004
# ...                    ...        ...           ...
# 16987                   10       2019       6854004
# 17002                   10       2019       6862008
# 17008                   10       2019       6864002
# 17016                   10       2019       6864177
# 17031                   10       2019       6872003
#
# [2973 rows x 201 columns]

# %%
same.to_csv("same_raw.csv", index = False)

# %%
test.to_csv("wide_raw.csv", index = False)

# %%
wide_raw = pd.read_csv("wide_raw.csv")

# %%
cols = list(wide_raw.columns)

tobeinserted = cols[390: 401]

tobeinserted

cols_sub = cols[0:389]

for i in range(len(tobeinserted) - 1, -1, -1):
    cols_sub.insert(22, tobeinserted[i])

cols_sub

test = wide_raw[cols_sub]

test["individual_id"] = wide_raw["individual_id"]

test

# %%
long_raw = pd.wide_to_long(test, ['family_interview_id',
       'psid_state_of_residence_code', 'family_composition_change', 'age',
       'sex', 'number_of_children_in_fu', '1968_family_identifier',
       'marital_status', 'health_status', 'race', 'religion', 'wtr_donated',
       'wtr_donated_to_health_org', 'amt_of_health_donations',
       'total_family_income', 'wealth_wo_equity',
       'wealth_with_equity', 'sequence_number',
       'relation_to_rp',  'year'],  i = ["individual_id"], j = "YEAR", sep = '-')
